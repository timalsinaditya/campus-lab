# %%
using Plots

k=-10:1:20
# Out:
# -10:1:20

# %%
signal1= -0.92 .* sin.(0.1*π.*k .- 3*π/4)
plot(signal1, xlabel="k", ylabel="Amplitude", title="7b")
scatter(k, signal1, marker=:hline, markersize=8, legend=false)
